# %% [markdown]
# <a href="https://colab.research.google.com/github/wailin-ow/ADALL_github/blob/main/Main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Example: Replace this with the raw URL of your GitHub file
github_raw_url = 'https://raw.githubusercontent.com/wailin-ow/ADALL_github/main/laptop_prices_2024_sgd_TL.csv'
try:
 df = pd.read_csv(github_raw_url)
 print("Successfully loaded data from GitHub!")
 display(df.head())
except Exception as e:
 print(f"Error loading data: {e}")
 print("Please ensure the URL is correct and the file format is compatible with `pd.read_csv`.")
# Out:
# Successfully loaded data from GitHub!
#   Brand                Model                        CPU              GPU  \
# 0  Acer             Aspire 5           Intel i9-14900HK  NVIDIA RTX 4070
# 1  Acer              Nitro 5         AMD Ryzen 9 8900HX  AMD Radeon 780M
# 2  Acer              Nitro 5          AMD Ryzen 5 8600H  NVIDIA RTX 4050
# 3  Acer        TravelMate P6  Intel Core Ultra 7 15500H  NVIDIA RTX 4060
# 4  Acer  Predator Helios 300            Intel i7-14800H  NVIDIA RTX 4070
#
#    RAM_GB Storage_Type  Storage_GB  Touchscreen  Weight_kg  Screen_Size_inch  \
# 0      64          SSD         256        False       1.56              16.0
# 1      32          SSD        1024         True       1.45              14.0
# 2      32          SSD        2048        False       1.34              14.0
# 3      16          SSD        4096         True       1.18              13.3
# 4       8          SSD        1024         True       1.31              14.0
#
#    Discount_percent  Price_SGD  Brand_Discount  Member_Discount
# 0              3.27    2413.36               5           144.80
# 1              5.03    1773.75               5           124.16
# 2              4.41    1634.07               5            98.04
# 3              2.16    2362.59               5           118.13
# 4              6.93    2218.55               5           155.30

# %%
# Load key from Google Colab Secrets
api_key = userdata.get('OPENAI_API_KEY')

client = OpenAI(
    # This is the default and can be omitted
    api_key=api_key,
)

response = client.responses.create(
    model="gpt-5-mini",
    instructions="You are a data analyst expert who uses Python.",
    input="What is Exploratory Data Analysis?",
)

print(response.output_text)
# Out:
# Exploratory Data Analysis (EDA) is the process of examining and summarizing a dataset to understand its main characteristics, uncover patterns and anomalies, test assumptions, and inform further modeling or decision-making. It is an early, iterative, and mostly visual stage of any data project that helps you form hypotheses and decide how to clean, transform, and model the data.
#
# Key goals
# - Understand structure: rows, columns, data types, unique values.
# - Assess data quality: missing values, duplicates, inconsistent entries.
# - Summarize distributions: central tendency, spread, skew, multimodality.
# - Detect outliers and anomalies.
# - Reveal relationships: correlations, group differences, dependencies.
# - Inform feature engineering and modelling choices (transformations, encodings, interactions).
# - Guide data cleaning and sampling strategies.
#
# Typical EDA workflow
# 1. Get to know the data: head, shape, dtypes.
# 2. Data quality checks: missing values, duplicates, inconsistent categories.
# 3. Univariate analysis: distributions for numerical and categorical variables.
# 4. Bivariate analysis: scatterplots, boxplots, contingency tables, correlations.
# 5. Multivariate exploration: pairplots, dimensionality reduction, clustering.
# 6. Summarize findings and next steps (cleaning, feature creation, modeling).
#
# Common techniques and visualizations
# - Numerical: histograms, KDEs, boxplots, violin plots, summary statistics (mean, median, std, IQR).
# - Categorical: bar charts, value counts, stacked bars, pivot tables.
# - Relationships: scatter plots, colored scatter (hue), regression lines, pairplots.
# - Correlation: correlation matrix and heatmap (Pearson/Spearman), cross-tabs.
# - Time series: line plots, seasonal decomposition.
# - Outliers: boxplots, z-scores, IQR method.
# - Missingness patterns: heatmaps, missingness matrix.
#
# Concise Python example (pandas + seaborn)
# ```python
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# df = pd.read_csv("data.csv")
#
# # Quick overview
# print(df.shape)
# print(df.dtypes)
# print(df.head())
#
# # Missing values & duplicates
# print(df.isnull().sum())
# print(df.duplicated().sum())
#
# # Summary stats
# print(df.describe(include='all'))
#
# # Univariate (numerical)
# df['age'].hist(bins=30); plt.title('Age distribution')
#
# # Categorical counts
# sns.countplot(data=df, x='gender')
#
# # Bivariate
# sns.scatterplot(data=df, x='age', y='income', hue='gender')
# sns.boxplot(data=df, x='churn', y='monthly_spend')
#
# # Correlation heatmap
# sns.heatmap(df.select_dtypes('number').corr(), annot=True, fmt=".2f")
# plt.show()
# ```
#
# Useful libraries and tools
# - pandas, numpy for data manipulation
# - matplotlib, seaborn, plotly for plotting
# - scikit-learn for preprocessing and dimensionality reduction (PCA)
# - pandas-profiling / ydata-profiling, Sweetviz, D-Tale for automated EDA reports
#
# Best practices
# - Start simple and iterate; combine visuals with numeric summaries.
# - Always check for data leakage and sampling bias.
# - Document assumptions and surprising findings.
# - Use transformations (log, boxcox) when distributions are skewed.
# - Be cautious interpreting correlations (causation vs correlation).
# - Communicate findings via clear charts and concise summaries.
#
# Deliverables from EDA
# - Data quality report (missingness, duplicates, inconsistent values)
# - Summary statistics and visualizations
# - List of recommended cleaning steps and feature ideas
# - Hypotheses and next steps for modeling or further analysis
#
# If you want, I can run a quick EDA on your dataset or generate an automated profile report (pandas-profiling) — upload a sample CSV and tell me what questions you care about.

# %%
# Convert the first few rows to a string to send to OpenAI
data_preview = df.head(10).to_csv(index=False)
print(data_preview)

response = client.responses.create(
  model="gpt-5-mini",
  instructions="You are an expert data scientist with extensive knowledge of predictive analysis and linear regression.",
  input=f"Dataset: Laptop Price Prdiction (1000 samples, 14 features, traget is Price_SGD)\nHere are the first 10 rows of the dataset:\n{data_preview}]",
)
print(response.output_text)
# Out:
# Brand,Model,CPU,GPU,RAM_GB,Storage_Type,Storage_GB,Touchscreen,Weight_kg,Screen_Size_inch,Discount_percent,Price_SGD,Brand_Discount,Member_Discount
# Acer,Aspire 5,Intel i9-14900HK,NVIDIA RTX 4070,64,SSD,256,False,1.56,16.0,3.27,2413.36,5,144.8
# Acer,Nitro 5,AMD Ryzen 9 8900HX,AMD Radeon 780M,32,SSD,1024,True,1.45,14.0,5.03,1773.75,5,124.16
# Acer,Nitro 5,AMD Ryzen 5 8600H,NVIDIA RTX 4050,32,SSD,2048,False,1.34,14.0,4.41,1634.07,5,98.04
# Acer,TravelMate P6,Intel Core Ultra 7 15500H,NVIDIA RTX 4060,16,SSD,4096,True,1.18,13.3,2.16,2362.59,5,118.13
# Acer,Predator Helios 300,Intel i7-14800H,NVIDIA RTX 4070,8,SSD,1024,True,1.31,14.0,6.93,2218.55,5,155.3
# Acer,Aspire 5,Intel i9-14900HK,NVIDIA RTX 4080,32,SSD,256,False,3.34,17.3,8.94,2224.12,5,155.69
# Acer,TravelMate P6,Intel i9-14900HK,NVIDIA RTX 4080,128,SSD,1024,True,1.11,13.3,11.72,3016.36,5,211.15
# Acer,Predator Helios 300,Intel Core Ultra 9 15700H,NVIDIA RTX 4070,16,SSD,2048,True,1.29,13.3,8.84,2579.29,5,180.55
# Acer,Swift 3,Intel i5-14500H,NVIDIA RTX 4050,64,SSD,4096,False,1.4,13.3,6.92,1976.94,5,98.85
# Acer,Nitro 5,Intel Core Ultra 9 15700H,NVIDIA RTX 4070,16,SSD,2048,False,1.15,13.3,5.25,2538.34,5,152.3
#
# Thanks — I can help build a predictive linear-regression solution for Price_SGD. Before I proceed with a full model I want to confirm your goal. Do you want:
# - a complete end-to-end modeling pipeline (preprocessing, feature engineering, cross-validated linear/regression models, hyperparameter tuning) with runnable Python code, or
# - a high-level plan and recommendations (features to create, pitfalls to avoid, what models to try), or
# - help interpreting a fitted linear model (coefficients, significance, diagnostics) if you already trained one?
#
# Below I give a compact, practical plan plus a ready-to-run Python pipeline (pandas + scikit-learn + statsmodels) that you can use/adapt. It covers preprocessing, encoding strategies for categorical, regularized linear models, model selection, evaluation, and diagnostics.
#
# 1) Quick plan / considerations
# - Clean & types:
#   - Convert Touchscreen to binary (0/1). Ensure numeric types for RAM_GB, Storage_GB, Weight_kg, Screen_Size_inch, Discount_percent, Brand_Discount, Member_Discount.
# - Missing values:
#   - Impute numerics (median) and categorical (constant or "Unknown").
# - Target distribution:
#   - Check skewness of Price_SGD. If skewed right, consider log(Price_SGD) as modeling target and inverse-transform predictions.
# - Categorical encoding:
#   - Brand (low-cardinality) → one-hot.
#   - Model, CPU, GPU (high-cardinality) → either frequency encoding or target encoding; another option: group into performance tiers if you can map specs to tiers.
#   - Storage_Type → one-hot.
# - Feature engineering:
#   - Total_Storage_GB (already Storage_GB) and maybe store Type interactions (SSD vs HDD).
#   - Effective_Discount = Discount_percent + Brand_Discount + Member_Discount (or test combining vs separate).
#   - Interaction terms: CPU*RAM, GPU*RAM, Screen_Size*Weight, Touchscreen*Screen_Size.
#   - Polynomial terms only if justified; use with regularization to avoid overfit.
# - Multicollinearity:
#   - Compute VIF; use Ridge/Lasso if VIF high or drop redundant features.
# - Model choices:
#   - Baseline: LinearRegression (OLS).
#   - Regularized: RidgeCV, LassoCV, ElasticNetCV (for stability and feature selection).
#   - If linearity insufficient, try tree-based models (RandomForest, XGBoost) as benchmarks.
# - Evaluation:
#   - Use k-fold CV (e.g., 5 or 10 folds). Metrics: RMSE, MAE, R^2. If log-target, compute RMSE on original scale (exp) or use RMSLE.
#   - Residual diagnostics: residuals vs fitted, QQ-plot, Breusch-Pagan test for heteroscedasticity.
# - Interpretability:
#   - Use statsmodels OLS for coefficient p-values (on simpler subset). For regularized models, use coefficient paths / permutation importance.
#
# 2) Example hands-on pipeline (pandas + scikit-learn + statsmodels)
# Copy/paste and adapt to your environment. This assumes df is your DataFrame.
#
# Python code:
# ```python
# import pandas as pd
# import numpy as np
#
# # modeling
# from sklearn.model_selection import cross_val_score, KFold, GridSearchCV, train_test_split
# from sklearn.pipeline import Pipeline
# from sklearn.compose import ColumnTransformer
# from sklearn.preprocessing import OneHotEncoder, StandardScaler, FunctionTransformer
# from sklearn.impute import SimpleImputer
# from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV
# from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
#
# # diagnostics
# import statsmodels.api as sm
# from statsmodels.stats.outliers_influence import variance_inflation_factor
#
# # Example: load df (you already have it). Ensure types:
# # df = pd.read_csv('laptops.csv')
#
# # Convert boolean strings to ints if needed
# df['Touchscreen'] = df['Touchscreen'].astype(str).str.lower().map({'true':1,'false':0}).fillna(0).astype(int)
#
# # Numeric features
# num_feats = ['RAM_GB','Storage_GB','Weight_kg','Screen_Size_inch',
#              'Discount_percent','Brand_Discount','Member_Discount']
#
# # Categorical: low-cardinality
# cat_low = ['Brand','Storage_Type']
#
# # High-cardinality categorical
# cat_high = ['Model','CPU','GPU']
#
# # Optional feature: combine discounts
# df['Total_Discount'] = df[['Discount_percent','Brand_Discount','Member_Discount']].sum(axis=1)
# num_feats.append('Total_Discount')
# # You can drop individual discount columns later or keep both sets for comparison.
#
# # Split
# X = df.drop(columns=['Price_SGD'])
# y = df['Price_SGD']
#
# # If target is skewed, try log transform:
# y_log = np.log1p(y)  # inverse: np.expm1(pred)
#
# # Preprocessing for numeric and categorical
# numeric_transformer = Pipeline([
#     ('imputer', SimpleImputer(strategy='median')),
#     ('scaler', StandardScaler())
# ])
#
# # For high-cardinality categoricals, use frequency encoding as a custom transformer:
# def freq_encode(X_col):
#     s = X_col.value_counts(normalize=True)
#     return X_col.map(s).fillna(0).values.reshape(-1,1)
#
# from sklearn.base import BaseEstimator, TransformerMixin
#
# class FrequencyEncoder(BaseEstimator, TransformerMixin):
#     def __init__(self):
#         self.maps = {}
#     def fit(self, X, y=None):
#         # X is DataFrame with columns
#         for col in X.columns:
#             self.maps[col] = X[col].value_counts(normalize=True)
#         return self
#     def transform(self, X):
#         out = []
#         for col in X.columns:
#             out.append(X[col].map(self.maps[col]).fillna(0).values.reshape(-1,1))
#         return np.hstack(out)
#
# high_cat_transformer = Pipeline([
#     ('freq', FrequencyEncoder())
# ])
#
# cat_low_transformer = Pipeline([
#     ('imputer', SimpleImputer(strategy='constant', fill_value='Unknown')),
#     ('onehot', OneHotEncoder(handle_unknown='ignore', sparse=False))
# ])
#
# preprocessor = ColumnTransformer(transformers=[
#     ('num', numeric_transformer, num_feats),
#     ('cat_low', cat_low_transformer, cat_low),
#     ('cat_high', high_cat_transformer, cat_high)
# ], remainder='drop')
#
# # Model pipeline: try RidgeCV (alpha grid) on log-target
# alphas = np.logspace(-3, 3, 30)
# pipe = Pipeline([
#     ('pre', preprocessor),
#     ('model', RidgeCV(alphas=alphas, scoring='neg_root_mean_squared_error', cv=5))
# ])
#
# # Train/validate with CV
# kf = KFold(n_splits=5, shuffle=True, random_state=42)
# scores = -cross_val_score(pipe, X, y_log, cv=kf, scoring='neg_root_mean_squared_error', n_jobs=-1)
# print("CV RMSE on log-target (mean):", scores.mean(), "std:", scores.std())
#
# # Fit on full train split, then evaluate on holdout
# X_train, X_test, y_train, y_test = train_test_split(X, y_log, test_size=0.2, random_state=42)
# pipe.fit(X_train, y_train)
# y_pred_log = pipe.predict(X_test)
# y_pred = np.expm1(y_pred_log)  # back to original scale
# y_test_orig = np.expm1(y_test)
#
# print("RMSE (original scale):", mean_squared_error(y_test_orig, y_pred, squared=False))
# print("MAE (orig scale):", mean_absolute_error(y_test_orig, y_pred))
# print("R2 (orig scale):", r2_score(y_test_orig, y_pred))
#
# # If you want interpretable OLS on a reduced feature set:
# X_proc = preprocessor.fit_transform(X)  # be careful: this creates numeric matrix
# # Optional: drop many columns or select k best features before OLS
# X_ols = sm.add_constant(X_proc)  # add intercept
# ols = sm.OLS(y_log, X_ols).fit()
# print(ols.summary())
#
# # VIF computation (on numeric matrix)
# # compute VIFs
# vif_data = pd.DataFrame()
# vif_data["feature"] = ['const'] + [f'X{i}' for i in range(X_proc.shape[1])]
# vif_data["VIF"] = [variance_inflation_factor(np.column_stack([np.ones(X_proc.shape[0]), X_proc]), i)
#                     for i in range(X_proc.shape[1]+1)]
# print(vif_data.head(20))
# ```
#
# Notes on the code and decisions:
# - I used frequency encoding for high-cardinality categories (Model, CPU, GPU). Frequency encoding is a simple, linear-friendly approach; target encoding is more powerful but requires careful CV usage to avoid leakage.
# - I used log1p(target) to stabilize variance; evaluate on original scale using expm1.
# - RidgeCV used to control coefficients and multicollinearity; LassoCV or ElasticNetCV can be swapped for sparsity/feature selection.
# - The statsmodels OLS is demonstrated on the fully processed matrix (but that matrix can be very wide and not directly interpretable without mapping column names back — consider creating a reduced feature set for a readable summary).
#
# 3) Diagnostics & checks to run after you have a candidate model
# - Plot predicted vs actual (and residuals vs fitted).
# - QQ-plot of residuals to assess normality.
# - Breusch-Pagan test for heteroscedasticity (statsmodels.stats.diagnostic.het_breuschpagan).
# - Partial dependence or permutation importance (if you want feature importances).
# - If LASSO zeroes many coefficients, inspect which categories/features were dropped.
#
# 4) Quick tips for your specific columns
# - RAM_GB, Storage_GB: scale and consider log transform if skewed.
# - Model, CPU, GPU: grouping into performance tiers will reduce noise and improve linear model interpretability. Example tiers: entry, mid, high, workstation (map by known model families).
# - Weight_kg and Screen_Size: often correlated (bigger screen → heavier). Check correlation/VIF and consider interaction term screen*weight.
# - Discount_percent and Brand/Member_Discount: these might be correlated — test collinearity. Consider combining into Total_Discount if it improves predictive power.
# - Touchscreen: binary; include interactions with screen size (touchscreens more common in compact 2-in-1s).
#
# If you want, I can:
# - Produce a cleaned pipeline tailored to your full dataset and return the top features,
# - Run feature importance and produce interpretable coefficient table (you'd need to share the full dataset or give me a sample and confirm you want me to run it),
# - Or simplify the code to use target encoding with leakage-safe CV.
#
# Which of those would you like next?
